# %% [markdown]
# # **Standard MLP Model - Karunarathne K.D.N.S. IT23259584**

# %%
# !pip install tensorflow keras pandas numpy scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.13/dist-packages (2.20.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.13/dist-packages (3.13.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (2.1.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.13/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.13/dist-packages (0.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from tensorflow) (26.3)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from tensorflow) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.83.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.13/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.13/dist-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.13/dist-packages (from keras) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from astunparse>=1.6.0->tensorflow) (0.48.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn) (3.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.7.22)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Ensure reproducibility
np.random.seed(42)
tf.random.set_seed(42)
print("Libraries loaded successfully.")
# Out:
# Libraries loaded successfully.

# %%
# df = pd.read_csv('data.csv')
# df.head()
df = pd.read_csv('/content/Cancer_Data.csv')

print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %% [markdown]
# # **2).Data loading and initial cleaning**
#
# *   List item
# *   List item

# %%
import pandas as pd

# %%
try:
    data = pd.read_csv('Cancer_Data.csv') # [1]

    # Check for the common redundant column (often unnamed at index 32) and drop it
    if 'Unnamed: 32' in data.columns:
        data = data.drop(['Unnamed: 32'], axis=1)

    print(f"Dataset shape: {data.shape}")
except FileNotFoundError:
    print("Error: 'data.csv' not found. Please ensure the file is in the correct directory.")
    exit()

# Identify Features (X) and Target (Y)
X = data.drop(['id', 'diagnosis'], axis=1) # [1]
Y = data['diagnosis']
# Out:
# Dataset shape: (569, 32)

# %% [markdown]
# # **3).EXPLORATORY DATA ANALYSIS (EDA) AND VISUALIZATIONS**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 3.1. Target Class Distribution
print("\n--- EDA: Target Class Distribution ---")
plt.figure(figsize=(6, 4))
sns.countplot(x='diagnosis', data=data, palette='viridis', hue='diagnosis', legend=False)
plt.title('Distribution of Diagnosis (Malignant vs. Benign)')
plt.show()
# Out:
# --- EDA: Target Class Distribution ---

# %%
# get the info about data frame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %%
# 3.2. Feature Correlation Heatmap
data_corr = data.copy()
data_corr['diagnosis'] = data_corr['diagnosis'].replace({'M': 1, 'B': 0})
mean_features = ['diagnosis'] + [col for col in data_corr.columns if 'mean' in col]
corr_matrix = data_corr[mean_features].corr()
# Out:
# /tmp/ipykernel_3483/4249977560.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_corr['diagnosis'] = data_corr['diagnosis'].replace({'M': 1, 'B': 0})

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt='.1f', cmap='coolwarm',
            linewidths=.5, linecolor='black')
plt.title('Correlation Heatmap of Mean Features')
plt.show()

# %%
data_corr['diagnosis'].value_counts()    # Begineer cancer -> 0 and Maligant Cancer -> 1
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
# Feature Selection

# First, convert the diagnosis column to numeric values
# Assuming 'M' is Malignant (1) and other values (like 'B' for Benign) are 0
data['diagnosis_numeric'] = data['diagnosis'].map({'M': 1, 'B': 0})  # Adjust mapping as needed

# Calculate correlational matrix using the numeric version
corr_matrix = data.corr(numeric_only=True)  # Ensure only numeric columns are used

# Use the numeric version of diagnosis for correlation
corr_target = corr_matrix['diagnosis_numeric']

# Filter for correlations greater than 0.5
corr_best = corr_target[corr_target > 0.5]

corr_best
# Out:
# radius_mean             0.730029
# perimeter_mean          0.742636
# area_mean               0.708984
# compactness_mean        0.596534
# concavity_mean          0.696360
# concave points_mean     0.776614
# radius_se               0.567134
# perimeter_se            0.556141
# area_se                 0.548236
# radius_worst            0.776454
# perimeter_worst         0.782914
# area_worst              0.733825
# compactness_worst       0.590998
# concavity_worst         0.659610
# concave points_worst    0.793566
# diagnosis_numeric       1.000000
# Name: diagnosis_numeric, dtype: float64

# %%
# plot to show the correlation with x and y labels
plt.figure(figsize=(10, 6))
corr_best.plot(kind='bar')
plt.title('Correlation with Target Variable')
plt.xlabel('Features')
plt.ylabel('Correlation Coefficient')
plt.show()

# %%
# 3.3. Distribution of a Key Feature (Radius Mean) by Diagnosis
print("\n--- EDA: Distribution of Radius Mean (Malignant vs. Benign) ---")
plt.figure(figsize=(7, 5))
sns.violinplot(x='diagnosis', y='radius_mean', data=data, palette=['lightcoral', 'skyblue']) #
plt.title('Radius Mean Distribution by Diagnosis')
plt.show()
# Out:
# --- EDA: Distribution of Radius Mean (Malignant vs. Benign) ---
# /tmp/ipykernel_3483/2405475627.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='diagnosis', y='radius_mean', data=data, palette=['lightcoral', 'skyblue']) #

# %% [markdown]
# # **4.DATA PREPROCESSING**

# %%
from sklearn.preprocessing import LabelEncoder

# 4.1. Target Encoding
encoder = LabelEncoder()
encoded_Y = encoder.fit_transform(Y) # [2]

# %%
TEST_SIZE_FINAL = 0.15
VAL_SIZE_RATIO = 0.1764 # (~15% of total samples for validation)

# %%
data_corr.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
from sklearn.model_selection import train_test_split

# Step 1: Split Full Training Set (85%) and Test Set (15%), stratified
X_train_full, X_test, Y_train_full, Y_test = train_test_split(
    X.values, encoded_Y, test_size=TEST_SIZE_FINAL, random_state=42, stratify=encoded_Y
)

# %%
# Step 2: Split Training Set into Training (70%) and Validation (15%)
X_train, X_val, Y_train, Y_val = train_test_split(
    X_train_full, Y_train_full, test_size=VAL_SIZE_RATIO, random_state=42, stratify=Y_train_full
)

# %% [markdown]
# # **5.DATA PREPROCESSING (CORRECTED: SCALE AFTER SPLIT) (10% Grading Weight)**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# 5.1. Fit ONLY on Training Data
X_train_scaled = scaler.fit_transform(X_train) # <-- CORRECT: Fit only on training data

# 5.2. Transform Validation and Test Data using Training Data's statistics
X_val_scaled = scaler.transform(X_val)       # <-- CORRECT: Transform (no fit)
X_test_scaled = scaler.transform(X_test)     # <-- CORRECT: Transform (no fit)

input_dim = X_train_scaled.shape[1]

print(f"\nData successfully split and scaled (Test Set leakage fixed).")
print(f"Input Dimension: {input_dim}")
# Out:
# Data successfully split and scaled (Test Set leakage fixed).
# Input Dimension: 30

# %% [markdown]
# # **6.MODEL ARCHITECTURE DEFINITION (Standard DNN - Enhanced Baseline)**

# %%
from tensorflow import keras

def create_baseline_dnn(input_dim):
    # Sequential API is used for the straightforward linear stack (Baseline)
    model = keras.Sequential(name="Baseline_DNN_M1")  # Removed the extra comma
    return model

model_m1 = create_baseline_dnn(input_dim)
print("\nModel Architecture (DNN Baseline):")
model_m1.summary()
# Out:
# Model Architecture (DNN Baseline):
# Model: "Baseline_DNN_M1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # **7.MODEL COMPILATION AND TRAINING**

# %%
import tensorflow as tf
from keras.callbacks import EarlyStopping

# First, define your model with layers
model_m1 = tf.keras.Sequential(name="Baseline_DNN_M1")

# Add layers to your model
model_m1.add(tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)))
model_m1.add(tf.keras.layers.Dense(32, activation='relu'))
model_m1.add(tf.keras.layers.Dense(1, activation='sigmoid'))  # Binary classification output

# Now compile the model
model_m1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

print("\nStarting Model Training (Max 200 epochs, controlled by EarlyStopping)...")
history_m1 = model_m1.fit(
    X_train_scaled, Y_train,
    epochs=200,
    batch_size=32,
    validation_data=(X_val_scaled, Y_val), # Use scaled validation data
    callbacks=[early_stopping],
    verbose=2
)
print("Model training finished.")
# Out:
# Starting Model Training (Max 200 epochs, controlled by EarlyStopping)...
# Epoch 1/200
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 - 3s - 210ms/step - accuracy: 0.4484 - auc: 0.8674 - loss: 0.6868 - val_accuracy: 0.6512 - val_auc: 0.9740 - val_loss: 0.5131
# Epoch 2/200
# 13/13 - 0s - 20ms/step - accuracy: 0.8690 - auc: 0.9801 - loss: 0.4197 - val_accuracy: 0.9651 - val_auc: 0.9942 - val_loss: 0.3243
# Epoch 3/200
# 13/13 - 0s - 19ms/step - accuracy: 0.9597 - auc: 0.9834 - loss: 0.2755 - val_accuracy: 0.9651 - val_auc: 0.9959 - val_loss: 0.2135
# Epoch 4/200
# 13/13 - 0s - 13ms/step - accuracy: 0.9597 - auc: 0.9830 - loss: 0.1924 - val_accuracy: 0.9651 - val_auc: 0.9991 - val_loss: 0.1487
# Epoch 5/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9597 - auc: 0.9869 - loss: 0.1462 - val_accuracy: 0.9767 - val_auc: 1.0000 - val_loss: 0.1141
# Epoch 6/200
# 13/13 - 0s - 10ms/step - accuracy: 0.9647 - auc: 0.9900 - loss: 0.1205 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0929
# Epoch 7/200
# 13/13 - 0s - 12ms/step - accuracy: 0.9723 - auc: 0.9918 - loss: 0.1037 - val_accuracy: 0.9884 - val_auc: 1.0000 - val_loss: 0.0812
# Epoch 8/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9773 - auc: 0.9934 - loss: 0.0924 - val_accuracy: 0.9884 - val_auc: 0.9994 - val_loss: 0.0742
# Epoch 9/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9798 - auc: 0.9940 - loss: 0.0838 - val_accuracy: 0.9884 - val_auc: 0.9997 - val_loss: 0.0668
# Epoch 10/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9773 - auc: 0.9950 - loss: 0.0770 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0655
# Epoch 11/200
# 13/13 - 0s - 12ms/step - accuracy: 0.9798 - auc: 0.9956 - loss: 0.0720 - val_accuracy: 0.9884 - val_auc: 0.9997 - val_loss: 0.0614
# Epoch 12/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9773 - auc: 0.9963 - loss: 0.0675 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0639
# Epoch 13/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9798 - auc: 0.9968 - loss: 0.0635 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0604
# Epoch 14/200
# 13/13 - 0s - 12ms/step - accuracy: 0.9824 - auc: 0.9970 - loss: 0.0601 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0581
# Epoch 15/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9824 - auc: 0.9974 - loss: 0.0570 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0564
# Epoch 16/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9824 - auc: 0.9977 - loss: 0.0540 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0572
# Epoch 17/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9824 - auc: 0.9981 - loss: 0.0515 - val_accuracy: 0.9767 - val_auc: 1.0000 - val_loss: 0.0529
# Epoch 18/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9824 - auc: 0.9983 - loss: 0.0489 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0553
# Epoch 19/200
# 13/13 - 0s - 10ms/step - accuracy: 0.9849 - auc: 0.9986 - loss: 0.0467 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0532
# Epoch 20/200
# 13/13 - 0s - 10ms/step - accuracy: 0.9874 - auc: 0.9989 - loss: 0.0446 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0584
# Epoch 21/200
# 13/13 - 0s - 13ms/step - accuracy: 0.9899 - auc: 0.9990 - loss: 0.0422 - val_accuracy: 0.9651 - val_auc: 0.9988 - val_loss: 0.0553
# Epoch 22/200
# 13/13 - 0s - 21ms/step - accuracy: 0.9899 - auc: 0.9991 - loss: 0.0408 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0526
# Epoch 23/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9874 - auc: 0.9992 - loss: 0.0388 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0537
# Epoch 24/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9899 - auc: 0.9993 - loss: 0.0366 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0576
# Epoch 25/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9924 - auc: 0.9996 - loss: 0.0343 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0559
# Epoch 26/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9924 - auc: 0.9996 - loss: 0.0330 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0535
# Epoch 27/200
# 13/13 - 0s - 12ms/step - accuracy: 0.9924 - auc: 0.9996 - loss: 0.0313 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0553
# Epoch 28/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9924 - auc: 0.9997 - loss: 0.0300 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0569
# Epoch 29/200
# 13/13 - 0s - 10ms/step - accuracy: 0.9924 - auc: 0.9998 - loss: 0.0284 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0544
# Epoch 30/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9924 - auc: 0.9997 - loss: 0.0276 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0501
# Epoch 31/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9924 - auc: 0.9999 - loss: 0.0256 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0555
# Epoch 32/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9924 - auc: 0.9999 - loss: 0.0242 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0569
# Epoch 33/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9924 - auc: 0.9999 - loss: 0.0232 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0538
# Epoch 34/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9924 - auc: 1.0000 - loss: 0.0218 - val_accuracy: 0.9767 - val_auc: 0.9977 - val_loss: 0.0586
# Epoch 35/200
# 13/13 - 0s - 10ms/step - accuracy: 0.9924 - auc: 1.0000 - loss: 0.0207 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0513
# Epoch 36/200
# 13/13 - 0s - 10ms/step - accuracy: 0.9924 - auc: 1.0000 - loss: 0.0196 - val_accuracy: 0.9767 - val_auc: 0.9977 - val_loss: 0.0568
# Epoch 37/200
# 13/13 - 0s - 10ms/step - accuracy: 0.9924 - auc: 1.0000 - loss: 0.0185 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0496
# Epoch 38/200
# 13/13 - 0s - 12ms/step - accuracy: 0.9950 - auc: 1.0000 - loss: 0.0178 - val_accuracy: 0.9767 - val_auc: 0.9977 - val_loss: 0.0583
# Epoch 39/200
# 13/13 - 0s - 10ms/step - accuracy: 0.9950 - auc: 1.0000 - loss: 0.0163 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0525
# Epoch 40/200
# 13/13 - 0s - 10ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0156 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0542
# Epoch 41/200
# 13/13 - 0s - 12ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0147 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0540
# Epoch 42/200
# 13/13 - 0s - 11ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0140 - val_accuracy: 0.9767 - val_auc: 0.9977 - val_loss: 0.0575
# Epoch 43/200
# 13/13 - 0s - 10ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0130 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0505
# Epoch 44/200
# 13/13 - 0s - 12ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0127 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0505
# Epoch 45/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0118 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0568
# Epoch 46/200
# 13/13 - 0s - 10ms/step - accuracy: 0.9975 - auc: 1.0000 - loss: 0.0115 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0502
# Epoch 47/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0103 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0526
# Epoch 48/200
# 13/13 - 0s - 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0098 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0554
# Epoch 49/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0095 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0522
# Epoch 50/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0091 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0552
# Epoch 51/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0086 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0506
# Epoch 52/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0080 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0495
# Epoch 53/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0077 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0538
# Epoch 54/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0075 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0407
# Epoch 55/200
# 13/13 - 0s - 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0069 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0491
# Epoch 56/200
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0066 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0533
# Epoch 57/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0062 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0536
# Epoch 58/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0062 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0392
# Epoch 59/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0058 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0499
# Epoch 60/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0054 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0519
# Epoch 61/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0053 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0481
# Epoch 62/200
# 13/13 - 0s - 13ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0048 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0539
# Epoch 63/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0049 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0516
# Epoch 64/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0043 - val_accuracy: 0.9767 - val_auc: 0.9994 - val_loss: 0.0474
# Epoch 65/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0043 - val_accuracy: 0.9767 - val_auc: 0.9988 - val_loss: 0.0509
# Epoch 66/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0041 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0540
# Epoch 67/200
# 13/13 - 0s - 11ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0039 - val_accuracy: 0.9767 - val_auc: 0.9986 - val_loss: 0.0518
# Epoch 68/200
# 13/13 - 0s - 10ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0037 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0564
# Epoch 69/200
# 13/13 - 0s - 12ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0037 - val_accuracy: 0.9767 - val_auc: 0.9986 - val_loss: 0.0520
# Epoch 70/200
# 13/13 - 0s - 16ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0034 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0559
# Epoch 71/200
# 13/13 - 0s - 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0033 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0549
# Epoch 72/200
# 13/13 - 0s - 15ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0032 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0563
# Epoch 73/200
# 13/13 - 0s - 24ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0031 - val_accuracy: 0.9767 - val_auc: 0.9986 - val_loss: 0.0536
# Epoch 74/200
# 13/13 - 0s - 18ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0030 - val_accuracy: 0.9767 - val_auc: 0.9983 - val_loss: 0.0574
# Epoch 75/200
# 13/13 - 0s - 22ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0029 - val_accuracy: 0.9767 - val_auc: 0.9977 - val_loss: 0.0581
# Epoch 76/200
# 13/13 - 0s - 15ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0028 - val_accuracy: 0.9767 - val_auc: 0.9977 - val_loss: 0.0606
# Epoch 77/200
# 13/13 - 0s - 19ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0027 - val_accuracy: 0.9767 - val_auc: 0.9980 - val_loss: 0.0588
# Epoch 78/200
# 13/13 - 0s - 17ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.0025 - val_accuracy: 0.9767 - val_auc: 0.9980 - val_loss: 0.0583
# Model training finished.

# %% [markdown]
# 8.MODEL EVALUATION

# %%
print("\nEvaluating Model on the held-out Test Set (15%):")
loss_m1, accuracy_m1, auc_m1 = model_m1.evaluate(X_test_scaled, Y_test, verbose=0) # Use scaled test data

print(f"\n--- Chathuka (Baseline DNN) Final Test Results ---")
print(f"Test Loss: {loss_m1:.4f}")
print(f"Test Accuracy: {accuracy_m1:.4f}")
print(f"Test AUC-ROC: {auc_m1:.4f}")

# Generate detailed classification report for comprehensive comparison
Y_pred_prob = model_m1.predict(X_test_scaled)
Y_pred_class = (Y_pred_prob > 0.5).astype("int32")

report = classification_report(Y_test, Y_pred_class, target_names=encoder.classes_)
print("\nClassification Report (Key Metrics for Comparison):")
print(report)

# %% [markdown]
# # **9.COMPREHENSIVE MODEL VISUALIZATION AND ANALYSIS**

# %%
# 9.1. Training History Visualization
plt.figure(figsize=(15, 5))

# Plot training history - Loss
plt.subplot(1, 3, 1)
plt.plot(history_m1.history['loss'], label='Training Loss', linewidth=2)
plt.plot(history_m1.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('Model Loss Over Epochs', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot training history - Accuracy
plt.subplot(1, 3, 2)
plt.plot(history_m1.history['accuracy'], label='Training Accuracy', linewidth=2)
plt.plot(history_m1.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('Model Accuracy Over Epochs', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot training history - AUC
plt.subplot(1, 3, 3)
plt.plot(history_m1.history['auc'], label='Training AUC', linewidth=2)
plt.plot(history_m1.history['val_auc'], label='Validation AUC', linewidth=2)
plt.title('Model AUC Over Epochs', fontsize=14, fontweight='bold')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Training completed after {len(history_m1.history['loss'])} epochs")
# Out:
# Training completed after 78 epochs

# %%
# 9.2. Confusion Matrix Visualization
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure Y_pred_class is defined for this cell
Y_pred_prob = model_m1.predict(X_test_scaled)
Y_pred_class = (Y_pred_prob > 0.5).astype("int32")

# Generate confusion matrix
cm = confusion_matrix(Y_test, Y_pred_class)

plt.figure(figsize=(12, 5))

# Confusion Matrix Heatmap
plt.subplot(1, 2, 1)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Benign', 'Malignant'],
            yticklabels=['Benign', 'Malignant'],
            cbar_kws={'label': 'Count'})
plt.title('Confusion Matrix', fontsize=14, fontweight='bold')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Normalized Confusion Matrix
cm_normalized = confusion_matrix(Y_test, Y_pred_class, normalize='true')
plt.subplot(1, 2, 2)
sns.heatmap(cm_normalized, annot=True, fmt='.2%', cmap='Blues',
            xticklabels=['Benign', 'Malignant'],
            yticklabels=['Benign', 'Malignant'],
            cbar_kws={'label': 'Percentage'})
plt.title('Normalized Confusion Matrix', fontsize=14, fontweight='bold')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

plt.tight_layout()
plt.show()

# Print confusion matrix details
print("Confusion Matrix Analysis:")
print(f"True Negatives (Benign correctly predicted): {cm[0,0]}")
print(f"False Positives (Benign predicted as Malignant): {cm[0,1]}")
print(f"False Negatives (Malignant predicted as Benign): {cm[1,0]}")
print(f"True Positives (Malignant correctly predicted): {cm[1,1]}")
print(f"Total Test Samples: {cm.sum()}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Confusion Matrix Analysis:
# True Negatives (Benign correctly predicted): 54
# False Positives (Benign predicted as Malignant): 0
# False Negatives (Malignant predicted as Benign): 1
# True Positives (Malignant correctly predicted): 31
# Total Test Samples: 86

# %%
# 9.3. ROC Curve and Precision-Recall Curve
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score

plt.figure(figsize=(15, 5))

# ROC Curve
fpr, tpr, _ = roc_curve(Y_test, Y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.subplot(1, 3, 1)
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Classifier')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve', fontsize=14, fontweight='bold')
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(Y_test, Y_pred_prob)
avg_precision = average_precision_score(Y_test, Y_pred_prob)

plt.subplot(1, 3, 2)
plt.plot(recall, precision, color='blue', lw=2, label=f'PR Curve (AP = {avg_precision:.4f})')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve', fontsize=14, fontweight='bold')
plt.legend(loc="lower left")
plt.grid(True, alpha=0.3)

# Prediction Probability Distribution
plt.subplot(1, 3, 3)
plt.hist(Y_pred_prob[Y_test == 0], bins=30, alpha=0.7, label='Benign', color='lightblue', density=True)
plt.hist(Y_pred_prob[Y_test == 1], bins=30, alpha=0.7, label='Malignant', color='lightcoral', density=True)
plt.axvline(x=0.5, color='black', linestyle='--', label='Decision Threshold')
plt.xlabel('Predicted Probability')
plt.ylabel('Density')
plt.title('Prediction Probability Distribution', fontsize=14, fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# 9.4. Model Performance Metrics Bar Chart
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Ensure model evaluation metrics and predictions are available
# Assuming model_m1, X_test_scaled, Y_test are available from previous cells
# Re-evaluate to define loss_m1, accuracy_m1, auc_m1
loss_m1, accuracy_m1, auc_m1 = model_m1.evaluate(X_test_scaled, Y_test, verbose=0)

# Re-predict to ensure Y_pred_prob and Y_pred_class are defined
Y_pred_prob = model_m1.predict(X_test_scaled)
Y_pred_class = (Y_pred_prob > 0.5).astype("int32")

# Calculate metrics for both classes
precision_benign = precision_score(Y_test, Y_pred_class, pos_label=0)
recall_benign = recall_score(Y_test, Y_pred_class, pos_label=0)
f1_benign = f1_score(Y_test, Y_pred_class, pos_label=0)

precision_malignant = precision_score(Y_test, Y_pred_class, pos_label=1)
recall_malignant = recall_score(Y_test, Y_pred_class, pos_label=1)
f1_malignant = f1_score(Y_test, Y_pred_class, pos_label=1)

# Overall metrics
overall_accuracy = accuracy_m1
overall_precision = precision_score(Y_test, Y_pred_class, average='weighted')
overall_recall = recall_score(Y_test, Y_pred_class, average='weighted')
overall_f1 = f1_score(Y_test, Y_pred_class, average='weighted')

plt.figure(figsize=(15, 10))

# Per-class metrics
plt.subplot(2, 2, 1)
metrics = ['Precision', 'Recall', 'F1-Score']
benign_scores = [precision_benign, recall_benign, f1_benign]
malignant_scores = [precision_malignant, recall_malignant, f1_malignant]

x = np.arange(len(metrics))
width = 0.35

plt.bar(x - width/2, benign_scores, width, label='Benign', color='lightblue', alpha=0.8)
plt.bar(x + width/2, malignant_scores, width, label='Malignant', color='lightcoral', alpha=0.8)

plt.xlabel('Metrics')
plt.ylabel('Score')
plt.title('Per-Class Performance Metrics', fontsize=14, fontweight='bold')
plt.xticks(x, metrics)
plt.legend()
plt.ylim([0, 1.1])
plt.grid(True, alpha=0.3, axis='y')

# Add value labels on bars
for i, (b, m) in enumerate(zip(benign_scores, malignant_scores)):
    plt.text(i - width/2, b + 0.01, f'{b:.3f}', ha='center', va='bottom', fontweight='bold')
    plt.text(i + width/2, m + 0.01, f'{m:.3f}', ha='center', va='bottom', fontweight='bold')

# Overall metrics
plt.subplot(2, 2, 2)
overall_metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'AUC-ROC']
overall_scores = [overall_accuracy, overall_precision, overall_recall, overall_f1, auc_m1]

bars = plt.bar(overall_metrics, overall_scores, color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd'], alpha=0.8)
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.title('Overall Model Performance', fontsize=14, fontweight='bold')
plt.ylim([0, 1.1])
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3, axis='y')

# Add value labels on bars
for bar, score in zip(bars, overall_scores):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.01, f'{score:.3f}',
             ha='center', va='bottom', fontweight='bold')

# Feature importance visualization (using correlation with target)
plt.subplot(2, 2, 3)
# Get top 10 most correlated features
top_features = corr_best.drop('diagnosis_numeric').nlargest(10)
plt.barh(range(len(top_features)), top_features.values, color='skyblue', alpha=0.8)
plt.yticks(range(len(top_features)), top_features.index, fontsize=10)
plt.xlabel('Correlation with Target')
plt.title('Top 10 Most Important Features', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3, axis='x')

# Model comparison with baseline (random classifier)
plt.subplot(2, 2, 4)
models = ['Random\nClassifier', 'Our DNN\nModel']
accuracies = [0.5, overall_accuracy]  # Random classifier has 50% accuracy for balanced classes
aucs = [0.5, auc_m1]  # Random classifier has 0.5 AUC

x = np.arange(len(models))
width = 0.35

plt.bar(x - width/2, accuracies, width, label='Accuracy', color='lightgreen', alpha=0.8)
plt.bar(x + width/2, aucs, width, label='AUC-ROC', color='orange', alpha=0.8)

plt.xlabel('Models')
plt.ylabel('Score')
plt.title('Model vs Random Classifier', fontsize=14, fontweight='bold')
plt.xticks(x, models)
plt.legend()
plt.ylim([0, 1.1])
plt.grid(True, alpha=0.3, axis='y')

# Add value labels
for i, (acc, auc_val) in enumerate(zip(accuracies, aucs)):
    plt.text(i - width/2, acc + 0.01, f'{acc:.3f}', ha='center', va='bottom', fontweight='bold')
    plt.text(i + width/2, auc_val + 0.01, f'{auc_val:.3f}', ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
# 9.5. Model Architecture Visualization and Summary
import matplotlib.patches as patches

plt.figure(figsize=(12, 8))

# Model architecture diagram
plt.subplot(2, 1, 1)
ax = plt.gca()

# Define layer positions and sizes
layers = [
    {'name': 'Input Layer', 'neurons': 30, 'pos': (1, 0.5), 'color': 'lightblue'},
    {'name': 'Hidden Layer 1', 'neurons': 64, 'pos': (3, 0.5), 'color': 'lightgreen'},
    {'name': 'Hidden Layer 2', 'neurons': 32, 'pos': (5, 0.5), 'color': 'lightcoral'},
    {'name': 'Output Layer', 'neurons': 1, 'pos': (7, 0.5), 'color': 'lightyellow'}
]

# Draw layers
for i, layer in enumerate(layers):
    # Draw rectangle for layer
    rect = patches.Rectangle((layer['pos'][0]-0.3, layer['pos'][1]-0.2), 0.6, 0.4,
                           linewidth=2, edgecolor='black', facecolor=layer['color'], alpha=0.7)
    ax.add_patch(rect)

    # Add layer text
    plt.text(layer['pos'][0], layer['pos'][1], f"{layer['name']}\n({layer['neurons']} neurons)",
             ha='center', va='center', fontweight='bold', fontsize=10)

    # Draw arrows between layers
    if i < len(layers) - 1:
        plt.arrow(layer['pos'][0] + 0.3, layer['pos'][1], 0.4, 0,
                 head_width=0.05, head_length=0.1, fc='black', ec='black')

plt.xlim(0, 8)
plt.ylim(0, 1)
plt.title('Neural Network Architecture', fontsize=16, fontweight='bold')
plt.axis('off')

# Model summary table
plt.subplot(2, 1, 2)
ax = plt.gca()
ax.axis('tight')
ax.axis('off')

# Create summary data
summary_data = [
    ['Layer Type', 'Output Shape', 'Parameters', 'Activation'],
    ['Dense (Input)', f'(None, 64)', f'{30 * 64 + 64:,}', 'ReLU'],
    ['Dense (Hidden)', f'(None, 32)', f'{64 * 32 + 32:,}', 'ReLU'],
    ['Dense (Output)', f'(None, 1)', f'{32 * 1 + 1:,}', 'Sigmoid'],
    ['', '', '', ''],
    ['Total Parameters', '', f'{(30*64+64) + (64*32+32) + (32*1+1):,}', ''],
    ['Training Data', f'{X_train_scaled.shape[0]} samples', '', ''],
    ['Validation Data', f'{X_val_scaled.shape[0]} samples', '', ''],
    ['Test Data', f'{X_test_scaled.shape[0]} samples', '', '']
]

table = plt.table(cellText=summary_data, cellLoc='center', loc='center',
                 colWidths=[0.25, 0.25, 0.25, 0.25])
table.auto_set_font_size(False)
table.set_fontsize(11)
table.scale(1, 2)

# Style the header row
for i in range(4):
    table[(0, i)].set_facecolor('#4CAF50')
    table[(0, i)].set_text_props(weight='bold', color='white')

# Style the summary rows
for i in range(4):
    table[(5, i)].set_facecolor('#E3F2FD')
    table[(6, i)].set_facecolor('#E3F2FD')
    table[(7, i)].set_facecolor('#E3F2FD')
    table[(8, i)].set_facecolor('#E3F2FD')

plt.title('Model Summary and Dataset Information', fontsize=14, fontweight='bold', pad=20)

plt.tight_layout()
plt.show()

# Print detailed model performance summary
print("\n" + "="*60)
print("           COMPREHENSIVE MODEL PERFORMANCE REPORT")
print("="*60)
print(f"📊 Dataset: Breast Cancer Wisconsin (Diagnostic)")
print(f"📈 Model: Deep Neural Network (3-layer architecture)")
print(f"🎯 Task: Binary Classification (Malignant vs Benign)")
print("\n📋 FINAL TEST RESULTS:")
print(f"   ✅ Test Accuracy: {accuracy_m1:.4f} ({accuracy_m1*100:.2f}%)")
print(f"   ✅ Test AUC-ROC:  {auc_m1:.4f} ({auc_m1*100:.2f}%)")
print(f"   ✅ Test Loss:     {loss_m1:.4f}")
print(f"   ✅ Precision:     {overall_precision:.4f} ({overall_precision*100:.2f}%)")
print(f"   ✅ Recall:        {overall_recall:.4f} ({overall_recall*100:.2f}%)")
print(f"   ✅ F1-Score:      {overall_f1:.4f} ({overall_f1*100:.2f}%)")
print("\n🏆 MODEL EXCELLENCE INDICATORS:")
print(f"   • High Accuracy: {accuracy_m1:.1%} - Excellent overall performance")
print(f"   • High AUC-ROC: {auc_m1:.1%} - Outstanding discrimination ability")
print(f"   • Low Loss: {loss_m1:.4f} - Well-calibrated predictions")
print(f"   • Balanced Performance: Good precision and recall for both classes")
print("="*60)
# Out:
# ============================================================
#            COMPREHENSIVE MODEL PERFORMANCE REPORT
# ============================================================
# 📊 Dataset: Breast Cancer Wisconsin (Diagnostic)
# 📈 Model: Deep Neural Network (3-layer architecture)
# 🎯 Task: Binary Classification (Malignant vs Benign)
#
# 📋 FINAL TEST RESULTS:
#    ✅ Test Accuracy: 0.9884 (98.84%)
#    ✅ Test AUC-ROC:  0.9829 (98.29%)
#    ✅ Test Loss:     0.0786
#    ✅ Precision:     0.9886 (98.86%)
#    ✅ Recall:        0.9884 (98.84%)
#    ✅ F1-Score:      0.9883 (98.83%)
#
# 🏆 MODEL EXCELLENCE INDICATORS:
#    • High Accuracy: 98.8% - Excellent overall performance
#    • High AUC-ROC: 98.3% - Outstanding discrimination ability
#    • Low Loss: 0.0786 - Well-calibrated predictions
#    • Balanced Performance: Good precision and recall for both classes
# ============================================================
